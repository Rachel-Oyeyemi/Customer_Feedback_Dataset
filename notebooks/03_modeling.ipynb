# %% [markdown]
# # 03 – Modeling

# %% [markdown]
# This notebook trains and evaluates the sentiment classification models.

# %%
from src.feature_engineering import create_tfidf_features
from src.train_model import train_models
input_csv = '../data/processed/sentiment_analysis_clean.csv'
features_path = '../data/processed/features.joblib'
labels_path = '../data/processed/labels.joblib'
vectorizer_path = '../data/processed/vectorizer.joblib'
create_tfidf_features(input_csv, features_path, labels_path, vectorizer_path)
train_models(features_path, labels_path, '../models/baseline_model.joblib', '../models/advanced_model.joblib')

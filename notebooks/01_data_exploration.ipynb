# %% [markdown]
# # 01 – Data Exploration

# %% [markdown]
# This notebook explores the raw customer feedback dataset.

# %%
import pandas as pd
df = pd.read_csv('../data/raw/sentiment_analysis.csv')
df.head()

# %% [markdown]
# # 02 – Preprocessing

# %% [markdown]
# This notebook demonstrates the preprocessing pipeline.

# %%
from src.preprocess import preprocess_dataset
input_path = '../data/raw/sentiment_analysis.csv'
output_path = '../data/processed/sentiment_analysis_clean.csv'
preprocess_dataset(input_path, output_path)
